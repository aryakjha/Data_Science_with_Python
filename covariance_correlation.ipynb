# %%
from numpy.random import randn
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from scipy.stats import pearsonr
from pandas .plotting import scatter_matrix
# %matplotlib inline

# %%
data1 = 20*randn(1000)+100
data2 = data1+(20*randn(1000)+50)

# %%
np.mean(data1),np.std(data1)
# Out:
# (100.09265555443545, 19.858201474274093)

# %%
np.mean(data2),np.std(data2)
# Out:
# (150.8292353389235, 28.54647801871352)

# %%
plt.scatter(data1,data2)

# %% [markdown]
# Covariance(x,y) = (1/(n-1))(sum((x-mean(x))(y-mean(y))))

# %%
covariance = np.cov(data1,data2)
covariance
# Out:
# array([[394.7429087 , 407.85433522],
#        [407.85433522, 815.7171244 ]])

# %% [markdown]
# Pearson's Correlation coefficient = covariance(x,y)/(stdv(y)*std(y))

# %%
corr,_ = pearsonr(data1,data2)

# %%
corr
# Out:
# 0.7187504418498858

# %% [markdown]
# IRIS flower dataset with 4 measurements : sepal width , sepal length , patalwidth , petal length

# %%
sns.set(color_codes = True, style='ticks')

# %%
iris = pd.read_csv('iris.csv')
iris.head(5)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
plotg = sns.pairplot(iris)

# %%
plotg22 = sns.pairplot(iris, vars = ['SepalWidthCm', 'SepalLengthCm'])

# %%
plotgg = sns.pairplot(iris,diag_kind = 'kde')
# Out:
# C:\Users\ARYA K JHA\Anaconda3\anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Diabetes dataset

# %%
data = pd.read_csv('diabetes.csv')

# %%
data.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# Deep copy and shallow copy in python

# %%
data_copy = data.copy(deep=True)

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data_copy
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 10             4      110             92              0        0  37.6
# 11            10      168             74              0        0  38.0
# ...

# %%
data_copy.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data_copy.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
pp = data_copy.hist(figsize =(20,10))

# %%
pd.plotting.scatter_matrix(data_copy,alpha=0.2,figsize=(25,25))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C84CFD1668>,
# ...
#       dtype=object)

# %%
df = pd.DataFrame(np.random.randn(1000,4),columns = ['A','B','C','D'])
pd.plotting.scatter_matrix(df,alpha = 0.2)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C84FFD1C50>,
# ...
#       dtype=object)

# %%
sns.pairplot(data_copy, hue='Outcome')
# Out:
# C:\Users\ARYA K JHA\Anaconda3\anaconda\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\ARYA K JHA\Anaconda3\anaconda\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\ARYA K JHA\Anaconda3\anaconda\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)

# %%
pp = sns.heatmap(data_copy.corr(),annot = True, cmap = 'RdYlGn')
